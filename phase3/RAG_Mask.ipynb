# %% [markdown]
# # RAG

# %% [markdown]
# ## Requirements

# %%
# %%capture
# !pip install transformers accelerate bitsandbytes langchain langchain-community sentence-transformers faiss-gpu pandas gdown

# %% [markdown]
# ## Dataset

# %%
# !gdown --fuzzy https://drive.google.com/file/d/1Lq2zVJlN_B4kUAu4VafQ4jXMIQiAR9vI/view?usp=sharing
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Lq2zVJlN_B4kUAu4VafQ4jXMIQiAR9vI
# From (redirected): https://drive.google.com/uc?id=1Lq2zVJlN_B4kUAu4VafQ4jXMIQiAR9vI&confirm=t&uuid=7c12be91-f013-46fb-b46e-f7ab04630371
# To: /content/IMDB_crawled.json
# 100% 292M/292M [00:01<00:00, 171MB/s]

# %% [markdown]
# ## Config

# %%
class Config:
    EMBEDDING_MODEL_NAME="thenlper/gte-base"
    LLM_MODEL_NAME="HuggingFaceH4/zephyr-7b-beta"
    K = 5 # top K retrieval

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd

df = pd.read_json('IMDB_crawled.json')

# %%
import os

os.makedirs('data', exist_ok=True)

# preprocess your data and only store the needed data as the context window for embedding model is limited
df = df[['title', 'first_page_summary', 'genres', 'rating']]
df.to_csv('/content/imdb.csv', index=False)

# %% [markdown]
# ## Vectorizer

# %% [markdown]
# load the CSV file and vectorize the rows using HuggingFaceEmbeddings.
# Store the results using FAISS vectorstore.
# Save the vectorestore in a pickle file for future usages.

# %%
import pickle

from langchain.document_loaders.csv_loader import CSVLoader
from langchain.vectorstores.utils import DistanceStrategy
from langchain.vectorstores.faiss import FAISS

from langchain_community.embeddings import HuggingFaceEmbeddings

# load the csv
csv_loader = CSVLoader('/content/imdb.csv', encoding='utf-8')
documents = csv_loader.load()

documents
# Out:
# [Document(page_content="title: The Godfather Part II\nfirst_page_summary: The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.\ngenres: ['Crime', 'Drama']\nrating: 9.0", metadata={'source': '/content/imdb.csv', 'row': 0}),
#  Document(page_content="title: The Lord of the Rings: The Fellowship of the Ring\nfirst_page_summary: A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.\ngenres: ['Action', 'Adventure', 'Drama']\nrating: 8.9", metadata={'source': '/content/imdb.csv', 'row': 1}),
#  Document(page_content="title: Pulp Fiction\nfirst_page_summary: The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption.\ngenres: ['Crime', 'Drama']\nrating: 8.9", metadata={'source': '/content/imdb.csv', 'row': 2}),
#  Document(page_content="title: The Godfather\nfirst_page_summary: The aging patriarch of an organized crime dynasty transfers control of his clandestine empire to his reluctant son.\ngenres: ['Crime', 'Drama']\nrating: 9.2", metadata={'source': '/content/imdb.csv', 'row': 3}),
#  Document(page_content="title: The Shawshank Redemption\nfirst_page_summary: Over the course of several years, two convicts form a friendship, seeking consolation and, eventually, redemption through basic compassion.\ngenres: ['Drama']\nrating: 9.3", metadata={'source': '/content/imdb.csv', 'row': 4}),
#  Document(page_content="title: Schindler's List\nfirst_page_summary: In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.\ngenres: ['Biography', 'Drama', 'History']\nrating: 9.0", metadata={'source': '/content/imdb.csv', 'row': 5}),
#  Document(page_content="title: One Flew Over the Cuckoo's Nest\nfirst_page_summary: In the Fall of 1963, a Korean War veteran and criminal pleads insanity and is admitted to a mental institution, where he rallies up the scared patients against the tyrannical nurse.\ngenres: ['Drama']\nrating: 8.7", metadata={'source': '/content/imdb.csv', 'row': 6}),
#  Document(page_content="title: Fight Club\nfirst_page_summary: An insomniac office worker and a devil-may-care soap maker form an underground fight club that evolves into much more.\ngenres: ['Drama']\nrating: 8.8", metadata={'source': '/content/imdb.csv', 'row': 7}),
#  Document(page_content="title: The Dark Knight\nfirst_page_summary: When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.\ngenres: ['Action', 'Crime', 'Drama']\nrating: 9.0", metadata={'source': '/content/imdb.csv', 'row': 8}),
#  Document(page_content="title: 12 Angry Men\nfirst_page_summary: The jury in a New York City murder trial is frustrated by a single member whose skeptical caution forces them to more carefully consider the evidence before jumping to a hasty verdict.\ngenres: ['Crime', 'Drama']\nrating: 9.0", metadata={'source': '/content/imdb.csv', 'row': 9}),
#  Document(page_content="title: The Matrix\nfirst_page_summary: When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.\ngenres: ['Action', 'Sci-Fi']\nrating: 8.7", metadata={'source': '/content/imdb.csv', 'row': 10}),
#  Document(page_content="title: The Lord of the Rings: The Two Towers\nfirst_page_summary: While Frodo and Sam edge closer to Mordor with the help of the shifty Gollum, the divided fellowship makes a stand against Sauron's new ally, Saruman, and his hordes of Isengard.\ngenres: ['Action', 'Adventure', 'Drama']\nrating: 8.8", metadata={'source': '/content/imdb.csv', 'row': 11}),
#  Document(page_content="title: The Lord of the Rings: The Return of the King\nfirst_page_summary: Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.\ngenres: ['Action', 'Adventure', 'Drama']\nrating: 9.0", metadata={'source': '/content/imdb.csv', 'row': 12}),
#  Document(page_content="title: Inception\nfirst_page_summary: A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the pro... Read all\ngenres: ['Action', 'Adventure', 'Sci-Fi']\nrating: 8.8", metadata={'source': '/content/imdb.csv', 'row': 13}),
#  Document(page_content="title: Forrest Gump\nfirst_page_summary: The history of the United States from the 1950s to the '70s unfolds from the perspective of an Alabama man with an IQ of 75, who yearns to be reunited with his childhood sweetheart.\ngenres: ['Drama', 'Romance']\nrating: 8.8", metadata={'source': '/content/imdb.csv', 'row': 14}),
#  Document(page_content="title: The Good, the Bad and the Ugly\nfirst_page_summary: A bounty hunting scam joins two men in an uneasy alliance against a third in a race to find a fortune in gold buried in a remote cemetery.\ngenres: ['Adventure', 'Western']\nrating: 8.8", metadata={'source': '/content/imdb.csv', 'row': 15}),
#  Document(page_content="title: Goodfellas\nfirst_page_summary: The story of Henry Hill and his life in the mafia, covering his relationship with his wife Karen and his mob partners Jimmy Conway and Tommy DeVito.\ngenres: ['Biography', 'Crime', 'Drama']\nrating: 8.7", metadata={'source': '/content/imdb.csv', 'row': 16}),
#  Document(page_content="title: Se7en\nfirst_page_summary: Two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his motives.\ngenres: ['Crime', 'Drama', 'Mystery']\nrating: 8.6", metadata={'source': '/content/imdb.csv', 'row': 17}),
#  Document(page_content="title: Dune: Part Two\nfirst_page_summary: Paul Atreides unites with Chani and the Fremen while seeking revenge against the conspirators who destroyed his family.\ngenres: ['Action', 'Adventure', 'Drama']\nrating: 8.9", metadata={'source': '/content/imdb.csv', 'row': 18}),
#  Document(page_content="title: Interstellar\nfirst_page_summary: When Earth becomes uninhabitable in the future, a farmer and ex-NASA pilot, Joseph Cooper, is tasked to pilot a spacecraft, along with a team of researchers, to find a new planet for humans.\ngenres: ['Adventure', 'Drama', 'Sci-Fi']\nrating: 8.7", metadata={'source': '/content/imdb.csv', 'row': 19}),
#  Document(page_content="title: It's a Wonderful Life\nfirst_page_summary: An angel is sent from Heaven to help a desperately frustrated businessman by showing him what life would have been like if he had never existed.\ngenres: ['Drama', 'Family', 'Fantasy']\nrating: 8.6", metadata={'source': '/content/imdb.csv', 'row': 20}),
#  Document(page_content="title: The Silence of the Lambs\nfirst_page_summary: A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.\ngenres: ['Crime', 'Drama', 'Thriller']\nrating: 8.6", metadata={'source': '/content/imdb.csv', 'row': 21}),
#  Document(page_content="title: Seven Samurai\nfirst_page_summary: Farmers from a village exploited by bandits hire a veteran samurai for protection, who gathers six other samurai to join him.\ngenres: ['Action', 'Drama']\nrating: 8.6", metadata={'source': '/content/imdb.csv', 'row': 22}),
#  Document(page_content="title: City of God\nfirst_page_summary: In the slums of Rio, two kids' paths diverge as one struggles to become a photographer and the other a kingpin.\ngenres: ['Crime', 'Drama']\nrating: 8.6", metadata={'source': '/content/imdb.csv', 'row': 23}),
#  Document(page_content="title: Saving Private Ryan\nfirst_page_summary: Following the Normandy Landings, a group of U.S. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.\ngenres: ['Drama', 'War']\nrating: 8.6", metadata={'source': '/content/imdb.csv', 'row': 24}),
#  Document(page_content="title: Life Is Beautiful\nfirst_page_summary: When an open-minded Jewish waiter and his son become victims of the Holocaust, he uses a perfect mixture of will, humor and imagination to protect his son from the dangers around their camp.\ngenres: ['Comedy', 'Drama', 'Romance']\nrating: 8.6", metadata={'source': '/content/imdb.csv', 'row': 25}),
#  Document(page_content="title: The Green Mile\nfirst_page_summary: A tale set on death row, where gentle giant John Coffey possesses the mysterious power to heal people's ailments. When the lead guard, Paul Edgecombe, recognizes John's gift, he tries to hel... Read all\ngenres: ['Crime', 'Drama', 'Fantasy']\nrating: 8.6", metadata={'source': '/content/imdb.csv', 'row': 26}),
#  Document(page_content="title: Terminator 2: Judgment Day\nfirst_page_summary: A cyborg, identical to the one who failed to kill Sarah Connor, must now protect her ten year old son John from an even more advanced and powerful cyborg.\ngenres: ['Action', 'Adventure', 'Sci-Fi']\nrating: 8.6", metadata={'source': '/content/imdb.csv', 'row': 27}),
#  Document(page_content="title: Back to the Future\nfirst_page_summary: Marty McFly, a 17-year-old high school student, is accidentally sent 30 years into the past in a time-traveling DeLorean invented by his close friend, the maverick scientist Doc Brown.\ngenres: ['Adventure', 'Comedy', 'Sci-Fi']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 28}),
#  Document(page_content="title: Psycho\nfirst_page_summary: A Phoenix secretary embezzles $40,000 from her employer's client, goes on the run and checks into a remote motel run by a young man under the domination of his mother.\ngenres: ['Horror', 'Mystery', 'Thriller']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 29}),
#  Document(page_content="title: The Pianist\nfirst_page_summary: During WWII, acclaimed Polish musician Wladyslaw faces various struggles as he loses contact with his family. As the situation worsens, he hides in the ruins of Warsaw in order to survive.\ngenres: ['Biography', 'Drama', 'Music']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 30}),
#  Document(page_content="title: Spirited Away\nfirst_page_summary: During her family's move to the suburbs, a sullen 10-year-old girl wanders into a world ruled by gods, witches and spirits, a world where humans are changed into beasts.\ngenres: ['Animation', 'Adventure', 'Family']\nrating: 8.6", metadata={'source': '/content/imdb.csv', 'row': 31}),
#  Document(page_content="title: Star Wars: Episode IV - A New Hope\nfirst_page_summary: Luke Skywalker joins forces with a Jedi Knight, a cocky pilot, a Wookiee and two droids to save the galaxy from the Empire's world-destroying battle station, while also attempting to rescue ... Read all\ngenres: ['Action', 'Adventure', 'Fantasy']\nrating: 8.6", metadata={'source': '/content/imdb.csv', 'row': 32}),
#  Document(page_content="title: Parasite\nfirst_page_summary: Greed and class discrimination threaten the newly formed symbiotic relationship between the wealthy Park family and the destitute Kim clan.\ngenres: ['Drama', 'Thriller']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 33}),
#  Document(page_content="title: Spider-Man: Across the Spider-Verse\nfirst_page_summary: Miles Morales catapults across the multiverse, where he encounters a team of Spider-People charged with protecting its very existence. When the heroes clash on how to handle a new threat, Mi... Read all\ngenres: ['Animation', 'Action', 'Adventure']\nrating: 8.6", metadata={'source': '/content/imdb.csv', 'row': 34}),
#  Document(page_content="title: Gladiator\nfirst_page_summary: A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery.\ngenres: ['Action', 'Adventure', 'Drama']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 35}),
#  Document(page_content="title: The Lion King\nfirst_page_summary: Lion prince Simba and his father are targeted by his bitter uncle, who wants to ascend the throne himself.\ngenres: ['Animation', 'Adventure', 'Drama']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 36}),
#  Document(page_content="title: Léon: The Professional\nfirst_page_summary: 12-year-old Mathilda is reluctantly taken in by Léon, a professional assassin, after her family is murdered. An unusual relationship forms as she becomes his protégée and learns the assassin... Read all\ngenres: ['Action', 'Crime', 'Drama']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 37}),
#  Document(page_content="title: The Departed\nfirst_page_summary: An undercover cop and a mole in the police attempt to identify each other while infiltrating an Irish gang in South Boston.\ngenres: ['Crime', 'Drama', 'Thriller']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 38}),
#  Document(page_content="title: American History X\nfirst_page_summary: Living a life marked by violence, neo-Nazi Derek finally goes to prison after killing two black youths. Upon his release, Derek vows to change; he hopes to prevent his brother, Danny, who id... Read all\ngenres: ['Crime', 'Drama']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 39}),
#  Document(page_content="title: The Prestige\nfirst_page_summary: After a tragic accident, two stage magicians in 1890s London engage in a battle to create the ultimate illusion while sacrificing everything they have to outwit each other.\ngenres: ['Drama', 'Mystery', 'Sci-Fi']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 40}),
#  Document(page_content="title: Whiplash\nfirst_page_summary: A promising young drummer enrolls at a cut-throat music conservatory where his dreams of greatness are mentored by an instructor who will stop at nothing to realize a student's potential.\ngenres: ['Drama', 'Music']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 41}),
#  Document(page_content="title: Grave of the Fireflies\nfirst_page_summary: A young boy and his little sister struggle to survive in Japan during World War II.\ngenres: ['Animation', 'Drama', 'War']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 42}),
#  Document(page_content="title: Harakiri\nfirst_page_summary: When a ronin requesting seppuku at a feudal lord's palace is told of the brutal suicide of another ronin who previously visited, he reveals how their pasts are intertwined - and in doing so ... Read all\ngenres: ['Action', 'Drama', 'Mystery']\nrating: 8.6", metadata={'source': '/content/imdb.csv', 'row': 43}),
#  Document(page_content="title: Casablanca\nfirst_page_summary: A cynical expatriate American cafe owner struggles to decide whether or not to help his former lover and her fugitive husband escape the Nazis in French Morocco.\ngenres: ['Drama', 'Romance', 'War']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 44}),
#  Document(page_content="title: The Usual Suspects\nfirst_page_summary: The sole survivor of a pier shoot-out tells the story of how a notorious criminal influenced the events that began with five criminals meeting in a seemingly random police lineup.\ngenres: ['Crime', 'Drama', 'Mystery']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 45}),
#  Document(page_content="title: The Intouchables\nfirst_page_summary: After he becomes a quadriplegic from a paragliding accident, an aristocrat hires a young man from the projects to be his caregiver.\ngenres: ['Comedy', 'Drama']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 46}),
#  Document(page_content="title: Cinema Paradiso\nfirst_page_summary: A filmmaker recalls his childhood when falling in love with the pictures at the cinema of his home village and forms a deep friendship with the cinema's projectionist.\ngenres: ['Drama', 'Romance']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 47}),
#  Document(page_content="title: Modern Times\nfirst_page_summary: The Tramp struggles to live in modern industrial society with the help of a young homeless woman.\ngenres: ['Comedy', 'Drama', 'Romance']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 48}),
#  Document(page_content="title: Rear Window\nfirst_page_summary: A photographer in a wheelchair spies on his neighbors from his Greenwich Village courtyard apartment window, and becomes convinced one of them has committed murder, despite the skepticism of... Read all\ngenres: ['Mystery', 'Thriller']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 49}),
#  Document(page_content="title: Once Upon a Time in the West\nfirst_page_summary: A mysterious stranger with a harmonica joins forces with a notorious desperado to protect a beautiful widow from a ruthless assassin working for the railroad.\ngenres: ['Western']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 50}),
#  Document(page_content="title: Alien\nfirst_page_summary: The crew of a commercial spacecraft encounters a deadly lifeform after investigating a mysterious transmission of unknown origin.\ngenres: ['Horror', 'Sci-Fi']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 51}),
#  Document(page_content="title: City Lights\nfirst_page_summary: With the aid of a wealthy erratic tippler, a dewy-eyed tramp who has fallen in love with a sightless flower girl accumulates money to be able to help her medically.\ngenres: ['Comedy', 'Drama', 'Romance']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 52}),
#  Document(page_content="title: 12th Fail\nfirst_page_summary: The real-life story of IPS Officer Manoj Kumar Sharma and IRS Officer Shraddha Joshi.\ngenres: ['Biography', 'Drama']\nrating: 9.0", metadata={'source': '/content/imdb.csv', 'row': 53}),
#  Document(page_content="title: Apocalypse Now\nfirst_page_summary: A U.S. Army officer serving in Vietnam is tasked with assassinating a renegade Special Forces Colonel who sees himself as a god.\ngenres: ['Drama', 'Mystery', 'War']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 54}),
#  Document(page_content="title: Django Unchained\nfirst_page_summary: With the help of a German bounty-hunter, a freed slave sets out to rescue his wife from a brutal plantation owner in Mississippi.\ngenres: ['Drama', 'Western']\nrating: 8.5", metadata={'source': '/content/imdb.csv', 'row': 55}),
#  Document(page_content="title: Memento\nfirst_page_summary: A man with short-term memory loss attempts to track down his wife's murderer.\ngenres: ['Mystery', 'Thriller']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 56}),
#  Document(page_content="title: WALL·E\nfirst_page_summary: In the distant future, a small waste-collecting robot inadvertently embarks on a space journey that will ultimately decide the fate of mankind.\ngenres: ['Animation', 'Adventure', 'Family']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 57}),
#  Document(page_content="title: Raiders of the Lost Ark\nfirst_page_summary: In 1936, archaeologist and adventurer Indiana Jones is hired by the U.S. government to find the Ark of the Covenant before the Nazis can obtain its awesome powers.\ngenres: ['Action', 'Adventure']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 58}),
#  Document(page_content="title: The Lives of Others\nfirst_page_summary: In 1984 East Berlin, an agent of the secret police, conducting surveillance on a writer and his lover, finds himself becoming increasingly absorbed by their lives.\ngenres: ['Drama', 'Mystery', 'Thriller']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 59}),
#  Document(page_content="title: Sunset Blvd.\nfirst_page_summary: A screenwriter develops a dangerous relationship with a faded film star determined to make a triumphant return.\ngenres: ['Drama', 'Film-Noir']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 60}),
#  Document(page_content="title: Avengers: Infinity War\nfirst_page_summary: The Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe.\ngenres: ['Action', 'Adventure', 'Sci-Fi']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 61}),
#  Document(page_content="title: Spider-Man: Into the Spider-Verse\nfirst_page_summary: Teen Miles Morales becomes the Spider-Man of his universe and must join with five spider-powered individuals from other dimensions to stop a threat for all realities.\ngenres: ['Animation', 'Action', 'Adventure']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 62}),
#  Document(page_content="title: Paths of Glory\nfirst_page_summary: After a failed attack on a German position, a general orders three soldiers, chosen at random, court-martialed for cowardice and their commanding officer must defend them.\ngenres: ['Drama', 'War']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 63}),
#  Document(page_content="title: The Shining\nfirst_page_summary: A family heads to an isolated hotel for the winter where a sinister presence influences the father into violence, while his psychic son sees horrific forebodings from both past and future.\ngenres: ['Drama', 'Horror']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 64}),
#  Document(page_content="title: Witness for the Prosecution\nfirst_page_summary: A veteran British barrister must defend his client in a murder trial that has surprise after surprise.\ngenres: ['Crime', 'Drama', 'Mystery']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 65}),
#  Document(page_content="title: The Great Dictator\nfirst_page_summary: Dictator Adenoid Hynkel tries to expand his empire while a poor Jewish barber tries to avoid persecution from Hynkel's regime.\ngenres: ['Comedy', 'Drama', 'War']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 66}),
#  Document(page_content="title: Aliens\nfirst_page_summary: Decades after surviving the Nostromo incident, Ellen Ripley is sent out to re-establish contact with a terraforming colony but finds herself battling the Alien Queen and her offspring.\ngenres: ['Action', 'Adventure', 'Sci-Fi']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 67}),
#  Document(page_content="title: Inglourious Basterds\nfirst_page_summary: In Nazi-occupied France during World War II, a plan to assassinate Nazi leaders by a group of Jewish U.S. soldiers coincides with a theatre owner's vengeful plans for the same.\ngenres: ['Adventure', 'Drama', 'War']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 68}),
#  Document(page_content="title: The Dark Knight Rises\nfirst_page_summary: Eight years after the Joker's reign of chaos, Batman is coerced out of exile with the assistance of the mysterious Selina Kyle in order to defend Gotham City from the vicious guerrilla terro... Read all\ngenres: ['Action', 'Drama', 'Thriller']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 69}),
#  Document(page_content="title: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb\nfirst_page_summary: An insane American general orders a bombing attack on the Soviet Union, triggering a path to nuclear holocaust that a war room full of politicians and generals frantically tries to stop.\ngenres: ['Comedy', 'War']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 70}),
#  Document(page_content="title: Oldboy\nfirst_page_summary: After being kidnapped and imprisoned for fifteen years, Oh Dae-Su is released, only to find that he must find his captor in five days.\ngenres: ['Action', 'Drama', 'Mystery']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 71}),
#  Document(page_content="title: American Beauty\nfirst_page_summary: A sexually frustrated suburban father has a mid-life crisis after becoming infatuated with his daughter's best friend.\ngenres: ['Drama']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 72}),
#  Document(page_content="title: Coco\nfirst_page_summary: Aspiring musician Miguel, confronted with his family's ancestral ban on music, enters the Land of the Dead to find his great-great-grandfather, a legendary singer.\ngenres: ['Animation', 'Adventure', 'Drama']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 73}),
#  Document(page_content="title: Toy Story\nfirst_page_summary: A cowboy doll is profoundly threatened and jealous when a new spaceman action figure supplants him as top toy in a boy's bedroom.\ngenres: ['Animation', 'Adventure', 'Comedy']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 74}),
#  Document(page_content="title: Amadeus\nfirst_page_summary: The life, success and troubles of Wolfgang Amadeus Mozart, as told by Antonio Salieri, the contemporaneous composer who was deeply jealous of Mozart's talent and claimed to have murdered him... Read all\ngenres: ['Biography', 'Drama', 'Music']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 75}),
#  Document(page_content="title: The Boat\nfirst_page_summary: A German U-boat stalks the frigid waters of the North Atlantic as its young crew experience the sheer terror and claustrophobic life of a submariner in World War II.\ngenres: ['Drama', 'War']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 76}),
#  Document(page_content="title: Braveheart\nfirst_page_summary: Scottish warrior William Wallace leads his countrymen in a rebellion to free his homeland from the tyranny of King Edward I of England.\ngenres: ['Biography', 'Drama', 'History']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 77}),
#  Document(page_content="title: Avengers: Endgame\nfirst_page_summary: After the devastating events of Avengers: Infinity War (2018), the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos' action... Read all\ngenres: ['Action', 'Adventure', 'Drama']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 78}),
#  Document(page_content="title: Joker\nfirst_page_summary: During the 1980s, a failed stand-up comedian is driven insane and turns to a life of crime and chaos in Gotham City while becoming an infamous psychopathic crime figure.\ngenres: ['Crime', 'Drama', 'Thriller']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 79}),
#  Document(page_content="title: Princess Mononoke\nfirst_page_summary: On a journey to find the cure for a Tatarigami's curse, Ashitaka finds himself in the middle of a war between the forest gods and Tatara, a mining colony. In this quest he also meets San, th... Read all\ngenres: ['Animation', 'Action', 'Adventure']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 80}),
#  Document(page_content="title: Good Will Hunting\nfirst_page_summary: Will Hunting, a janitor at M.I.T., has a gift for mathematics, but needs help from a psychologist to find direction in his life.\ngenres: ['Drama', 'Romance']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 81}),
#  Document(page_content="title: Your Name.\nfirst_page_summary: Two teenagers share a profound, magical connection upon discovering they are swapping bodies. Things manage to become even more complicated when the boy and girl decide to meet in person.\ngenres: ['Animation', 'Drama', 'Fantasy']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 82}),
#  Document(page_content="title: Once Upon a Time in America\nfirst_page_summary: A former Prohibition-era Jewish gangster returns to the Lower East Side of Manhattan 35 years later, where he must once again confront the ghosts and regrets of his old life.\ngenres: ['Crime', 'Drama']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 83}),
#  Document(page_content="title: High and Low\nfirst_page_summary: An executive of a Yokohama shoe company becomes a victim of extortion when his chauffeur's son is kidnapped by mistake and held for ransom.\ngenres: ['Crime', 'Drama', 'Mystery']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 84}),
#  Document(page_content="title: 3 Idiots\nfirst_page_summary: Two friends are searching for their long lost companion. They revisit their college days and recall the memories of their friend who inspired them to think differently, even as the rest of t... Read all\ngenres: ['Comedy', 'Drama']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 85}),
#  Document(page_content="title: Oppenheimer\nfirst_page_summary: The story of American scientist J. Robert Oppenheimer and his role in the development of the atomic bomb.\ngenres: ['Biography', 'Drama', 'History']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 86}),
#  Document(page_content="title: Singin' in the Rain\nfirst_page_summary: A silent film star falls for a chorus girl just as he and his delusionally jealous screen partner are trying to make the difficult transition to talking pictures in 1920s Hollywood.\ngenres: ['Comedy', 'Musical', 'Romance']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 87}),
#  Document(page_content="title: Capernaum\nfirst_page_summary: While serving a five-year sentence for a violent crime, a 12-year-old boy sues his parents for neglect.\ngenres: ['Drama']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 88}),
#  Document(page_content="title: Requiem for a Dream\nfirst_page_summary: The drug-induced utopias of four Coney Island people are shattered when their addictions run deep.\ngenres: ['Drama']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 89}),
#  Document(page_content="title: Come and See\nfirst_page_summary: After finding an old rifle, a young boy joins the Soviet resistance movement against ruthless German forces and experiences the horrors of World War II.\ngenres: ['Drama', 'Thriller', 'War']\nrating: 8.4", metadata={'source': '/content/imdb.csv', 'row': 90}),
#  Document(page_content="title: Toy Story 3\nfirst_page_summary: The toys are mistakenly delivered to a day-care center instead of the attic right before Andy leaves for college, and it's up to Woody to convince the other toys that they weren't abandoned ... Read all\ngenres: ['Animation', 'Adventure', 'Comedy']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 91}),
#  Document(page_content="title: Eternal Sunshine of the Spotless Mind\nfirst_page_summary: When their relationship turns sour, a couple undergoes a medical procedure to have each other erased from their memories for ever.\ngenres: ['Drama', 'Romance', 'Sci-Fi']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 92}),
#  Document(page_content="title: The Hunt\nfirst_page_summary: A teacher lives a lonely life, all the while struggling over his son's custody. His life slowly gets better as he finds love and receives good news from his son, but his new luck is about to... Read all\ngenres: ['Drama']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 93}),
#  Document(page_content="title: Star Wars: Episode VI - Return of the Jedi\nfirst_page_summary: After rescuing Han Solo from Jabba the Hutt, the Rebels attempt to destroy the second Death Star, while Luke struggles to help Darth Vader back from the dark side.\ngenres: ['Action', 'Adventure', 'Fantasy']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 94}),
#  Document(page_content="title: 2001: A Space Odyssey\nfirst_page_summary: After uncovering a mysterious artifact buried beneath the Lunar surface, a spacecraft is sent to Jupiter to find its origins: a spacecraft manned by two men and the supercomputer HAL 9000.\ngenres: ['Adventure', 'Sci-Fi']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 95}),
#  Document(page_content="title: Reservoir Dogs\nfirst_page_summary: When a simple jewelry heist goes horribly wrong, the surviving criminals begin to suspect that one of them is a police informant.\ngenres: ['Crime', 'Thriller']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 96}),
#  Document(page_content="title: Ikiru\nfirst_page_summary: A bureaucrat tries to find meaning in his life after he discovers he has terminal cancer.\ngenres: ['Drama']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 97}),
#  Document(page_content="title: Lawrence of Arabia\nfirst_page_summary: The story of T.E. Lawrence, the English officer who successfully united and led the diverse, often warring, Arab tribes during World War I in order to fight the Turks.\ngenres: ['Adventure', 'Biography', 'Drama']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 98}),
#  Document(page_content="title: The Apartment\nfirst_page_summary: A Manhattan insurance clerk tries to rise in his company by letting its executives use his apartment for trysts, but complications and a romance of his own ensue.\ngenres: ['Comedy', 'Drama', 'Romance']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 99}),
#  Document(page_content="title: Citizen Kane\nfirst_page_summary: Following the death of publishing tycoon Charles Foster Kane, reporters scramble to uncover the meaning of his final utterance: 'Rosebud.'\ngenres: ['Drama', 'Mystery']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 100}),
#  Document(page_content="title: North by Northwest\nfirst_page_summary: A New York City advertising executive goes on the run after being mistaken for a government agent by a group of foreign spies, and falls for a woman whose loyalties he begins to doubt.\ngenres: ['Action', 'Adventure', 'Mystery']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 101}),
#  Document(page_content="title: M\nfirst_page_summary: When the police in a German city are unable to catch a child-murderer, other criminals join in the manhunt.\ngenres: ['Crime', 'Mystery', 'Thriller']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 102}),
#  Document(page_content="title: Vertigo\nfirst_page_summary: A former San Francisco police detective juggles wrestling with his personal demons and becoming obsessed with the hauntingly beautiful woman he has been hired to trail, who may be deeply dis... Read all\ngenres: ['Mystery', 'Romance', 'Thriller']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 103}),
#  Document(page_content="title: Incendies\nfirst_page_summary: Twins journey to the Middle East to discover their family history and fulfill their mother's last wishes.\ngenres: ['Drama', 'Mystery', 'War']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 104}),
#  Document(page_content="title: Double Indemnity\nfirst_page_summary: A Los Angeles insurance representative lets an alluring housewife seduce him into a scheme of insurance fraud and murder that arouses the suspicion of his colleague, an insurance investigato... Read all\ngenres: ['Crime', 'Drama', 'Film-Noir']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 105}),
#  Document(page_content="title: Scarface\nfirst_page_summary: In 1980 Miami, a determined Cuban immigrant takes over a drug cartel and succumbs to greed.\ngenres: ['Crime', 'Drama']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 106}),
#  Document(page_content="title: Amélie\nfirst_page_summary: Despite being caught in her imaginative world, Amelie, a young waitress, decides to help people find happiness. Her quest to spread joy leads her on a journey where she finds true love.\ngenres: ['Comedy', 'Romance']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 107}),
#  Document(page_content="title: Full Metal Jacket\nfirst_page_summary: A pragmatic U.S. Marine observes the dehumanizing effects the Vietnam War has on his fellow recruits from their brutal boot camp training to the bloody street fighting in Hue.\ngenres: ['Drama', 'War']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 108}),
#  Document(page_content="title: Heat\nfirst_page_summary: A group of high-end professional thieves start to feel the heat from the LAPD when they unknowingly leave a verbal clue at their latest heist.\ngenres: ['Action', 'Crime', 'Drama']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 109}),
#  Document(page_content="title: A Clockwork Orange\nfirst_page_summary: In the future, a sadistic gang leader is imprisoned and volunteers for a conduct-aversion experiment, but it doesn't go as planned.\ngenres: ['Crime', 'Sci-Fi']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 110}),
#  Document(page_content="title: Up\nfirst_page_summary: 78-year-old Carl Fredricksen travels to Paradise Falls in his house equipped with balloons, inadvertently taking a young stowaway.\ngenres: ['Animation', 'Adventure', 'Comedy']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 111}),
#  Document(page_content="title: To Kill a Mockingbird\nfirst_page_summary: Atticus Finch, a widowed lawyer in Depression-era Alabama, defends a Black man against an undeserved rape charge, and tries to educate his young children against prejudice.\ngenres: ['Crime', 'Drama']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 112}),
#  Document(page_content="title: The Sting\nfirst_page_summary: Two grifters team up to pull off the ultimate con.\ngenres: ['Comedy', 'Crime', 'Drama']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 113}),
#  Document(page_content="title: A Separation\nfirst_page_summary: A married couple are faced with a difficult decision - to improve the life of their child by moving to another country or to stay in Iran and look after a deteriorating parent who has Alzhei... Read all\ngenres: ['Drama']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 114}),
#  Document(page_content="title: Indiana Jones and the Last Crusade\nfirst_page_summary: In 1938, after his father goes missing while pursuing the Holy Grail, Indiana Jones finds himself up against the Nazis again to stop them from obtaining its powers.\ngenres: ['Action', 'Adventure']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 115}),
#  Document(page_content="title: Die Hard\nfirst_page_summary: A New York City police officer tries to save his estranged wife and several others taken hostage by terrorists during a Christmas party at the Nakatomi Plaza in Los Angeles.\ngenres: ['Action', 'Thriller']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 116}),
#  Document(page_content="title: Metropolis\nfirst_page_summary: In a futuristic city sharply divided between the working class and the city planners, the son of the city's mastermind falls in love with a working-class prophet who predicts the coming of a... Read all\ngenres: ['Drama', 'Sci-Fi']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 117}),
#  Document(page_content="title: Like Stars on Earth\nfirst_page_summary: An eight-year-old boy is thought to be a lazy trouble-maker, until the new art teacher has the patience and compassion to discover the real problem behind his struggles in school.\ngenres: ['Drama', 'Family']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 118}),
#  Document(page_content="title: Hamilton\nfirst_page_summary: The real life of one of America's foremost founding fathers and first Secretary of the Treasury, Alexander Hamilton. Captured live on Broadway from the Richard Rodgers Theater with the origi... Read all\ngenres: ['Biography', 'Drama', 'History']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 119}),
#  Document(page_content="title: Snatch\nfirst_page_summary: Unscrupulous boxing promoters, violent bookmakers, a Russian gangster, incompetent amateur robbers and supposedly Jewish jewelers fight to track down a priceless stolen diamond.\ngenres: ['Comedy', 'Crime']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 120}),
#  Document(page_content="title: L.A. Confidential\nfirst_page_summary: As corruption grows in 1950s Los Angeles, three policemen - one strait-laced, one brutal, and one sleazy - investigate a series of murders with their own brand of justice.\ngenres: ['Crime', 'Drama', 'Mystery']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 121}),
#  Document(page_content="title: Bicycle Thieves\nfirst_page_summary: In post-war Italy, a working-class man's bicycle is stolen, endangering his efforts to find work. He and his son set out to find it.\ngenres: ['Drama']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 122}),
#  Document(page_content="title: 1917\nfirst_page_summary: April 6th, 1917. As an infantry battalion assembles to wage war deep in enemy territory, two soldiers are assigned to race against time and deliver a message that will stop 1,600 men from wa... Read all\ngenres: ['Action', 'Drama', 'War']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 123}),
#  Document(page_content="title: Taxi Driver\nfirst_page_summary: A mentally unstable veteran works as a nighttime taxi driver in New York City, where the perceived decadence and sleaze fuels his urge for violent action.\ngenres: ['Crime', 'Drama']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 124}),
#  Document(page_content="title: Downfall\nfirst_page_summary: Traudl Junge, the final secretary for Adolf Hitler, tells of the Nazi dictator's final days in his Berlin bunker at the end of WWII.\ngenres: ['Biography', 'Drama', 'History']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 125}),
#  Document(page_content="title: Dangal\nfirst_page_summary: Former wrestler Mahavir Singh Phogat and his two wrestler daughters struggle towards glory at the Commonwealth Games in the face of societal oppression.\ngenres: ['Action', 'Biography', 'Drama']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 126}),
#  Document(page_content="title: For a Few Dollars More\nfirst_page_summary: Two bounty hunters with the same intentions team up to track down a gang of outlaws led by a psychotic Mexican bandit, who is plotting an audacious bank robbery.\ngenres: ['Drama', 'Western']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 127}),
#  Document(page_content="title: Batman Begins\nfirst_page_summary: After witnessing his parents' death, Bruce learns the art of fighting to confront injustice. When he returns to Gotham as Batman, he must stop a secret society that intends to destroy the ci... Read all\ngenres: ['Action', 'Crime', 'Drama']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 128}),
#  Document(page_content="title: The Wolf of Wall Street\nfirst_page_summary: Based on the true story of Jordan Belfort, from his rise to a wealthy stock-broker living the high life to his fall involving crime, corruption and the federal government.\ngenres: ['Biography', 'Comedy', 'Crime']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 129}),
#  Document(page_content="title: Some Like It Hot\nfirst_page_summary: After two male musicians witness a mob hit, they flee the state in an all-female band disguised as women, but further complications set in.\ngenres: ['Comedy', 'Music', 'Romance']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 130}),
#  Document(page_content="title: The Kid\nfirst_page_summary: The Tramp cares for an abandoned child, but events put their relationship in jeopardy.\ngenres: ['Comedy', 'Drama', 'Family']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 131}),
#  Document(page_content="title: Green Book\nfirst_page_summary: A working-class Italian-American bouncer becomes the driver for an African-American classical pianist on a tour of venues through the 1960s American South.\ngenres: ['Biography', 'Comedy', 'Drama']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 132}),
#  Document(page_content="title: The Father\nfirst_page_summary: A man refuses all assistance from his daughter as he ages. As he tries to make sense of his changing circumstances, he begins to doubt his loved ones, his own mind and even the fabric of his... Read all\ngenres: ['Drama', 'Mystery']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 133}),
#  Document(page_content="title: Judgment at Nuremberg\nfirst_page_summary: In 1948, an American court in occupied Germany tries four Nazis judged for war crimes.\ngenres: ['Drama', 'War']\nrating: 8.3", metadata={'source': '/content/imdb.csv', 'row': 134}),
#  Document(page_content="title: Top Gun: Maverick\nfirst_page_summary: After thirty years, Maverick is still pushing the envelope as a top naval aviator, but must confront ghosts of his past when he leads TOP GUN's elite graduates on a mission that demands the ... Read all\ngenres: ['Action', 'Drama']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 135}),
#  Document(page_content="title: All About Eve\nfirst_page_summary: A seemingly timid but secretly ruthless ingénue insinuates herself into the lives of an aging Broadway star and her circle of theater friends.\ngenres: ['Drama']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 136}),
#  Document(page_content="title: The Truman Show\nfirst_page_summary: An insurance salesman discovers his whole life is actually a reality TV show.\ngenres: ['Comedy', 'Drama']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 137}),
#  Document(page_content="title: Casino\nfirst_page_summary: In Las Vegas, two best friends - a casino executive and a mafia enforcer - compete for a gambling empire and a fast-living, fast-loving socialite.\ngenres: ['Crime', 'Drama']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 138}),
#  Document(page_content="title: Shutter Island\nfirst_page_summary: Teddy Daniels and Chuck Aule, two US marshals, are sent to an asylum on a remote island in order to investigate the disappearance of a patient, where Teddy uncovers a shocking truth about th... Read all\ngenres: ['Mystery', 'Thriller']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 139}),
#  Document(page_content="title: There Will Be Blood\nfirst_page_summary: A story of family, religion, hatred, oil and madness, focusing on a turn-of-the-century prospector in the early days of the business.\ngenres: ['Drama']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 140}),
#  Document(page_content="title: Ran\nfirst_page_summary: In Medieval Japan, an elderly warlord retires, handing over his empire to his three sons. However, he vastly underestimates how the new-found power will corrupt them and cause them to turn o... Read all\ngenres: ['Action', 'Drama', 'War']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 141}),
#  Document(page_content="title: Jurassic Park\nfirst_page_summary: A pragmatic paleontologist touring an almost complete theme park on an island in Central America is tasked with protecting a couple of kids after a power failure causes the park's cloned din... Read all\ngenres: ['Action', 'Adventure', 'Sci-Fi']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 142}),
#  Document(page_content="title: The Sixth Sense\nfirst_page_summary: Malcolm Crowe, a child psychologist, starts treating a young boy, Cole, who encounters dead people and convinces him to help them. In turn, Cole helps Malcolm reconcile with his estranged wi... Read all\ngenres: ['Drama', 'Mystery', 'Thriller']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 143}),
#  Document(page_content="title: Pan's Labyrinth\nfirst_page_summary: In the Falangist Spain of 1944, the bookish young stepdaughter of a sadistic army officer escapes into an eerie but captivating fantasy world.\ngenres: ['Drama', 'Fantasy', 'War']\nrating: 8.2", metadata={'source': '/content/imdb.csv', 'row': 144}),
# ...
#  Document(page_content="title: Chennai Express\nfirst_page_summary: A man travelling to Rameswaram via Chennai express for his late grandfather's ashes immersion finds himself in trouble after helping a don's daughter and her cousins board the train.\ngenres: ['Action', 'Comedy', 'Drama']\nrating: 6.1", metadata={'source': '/content/imdb.csv', 'row': 952}),
#  Document(page_content="title: The Lower Depths\nfirst_page_summary: In a Japanese slum, various residents play out their lives, dreaming of better things or settling for their lot. Among them is a man who pines for a young woman but is stymied by her decepti... Read all\ngenres: ['Drama']\nrating: 7.2", metadata={'source': '/content/imdb.csv', 'row': 953}),
#  Document(page_content="title: The Idiot\nfirst_page_summary: A Japanese veteran, driven partially mad from the war, travels to the snowy island of Hokkaido where he soon enters a love triangle with his best friend and a disgraced woman.\ngenres: ['Drama', 'Romance']\nrating: 7.2", metadata={'source': '/content/imdb.csv', 'row': 954}),
#  Document(page_content="title: Scandal\nfirst_page_summary: A celebrity photograph sparks a court case as a tabloid magazine spins a scandalous yarn over a painter and a famous singer.\ngenres: ['Drama']\nrating: 7.2", metadata={'source': '/content/imdb.csv', 'row': 955}),
#  Document(page_content="title: Saltburn\nfirst_page_summary: A student at Oxford University finds himself drawn into the world of a charming and aristocratic classmate, who invites him to his eccentric family's sprawling estate for a summer never to b... Read all\ngenres: ['Comedy', 'Drama', 'Thriller']\nrating: 7.0", metadata={'source': '/content/imdb.csv', 'row': 956}),
#  Document(page_content="title: Everything Everywhere All at Once\nfirst_page_summary: A middle-aged Chinese immigrant is swept up into an insane adventure in which she alone can save existence by exploring other universes and connecting with the lives she could have led.\ngenres: ['Action', 'Adventure', 'Comedy']\nrating: 7.8", metadata={'source': '/content/imdb.csv', 'row': 957}),
#  Document(page_content="title: La La Land\nfirst_page_summary: While navigating their careers in Los Angeles, a pianist and an actress fall in love while attempting to reconcile their aspirations for the future.\ngenres: ['Comedy', 'Drama', 'Music']\nrating: 8.0", metadata={'source': '/content/imdb.csv', 'row': 958}),
#  Document(page_content="title: Past Lives\nfirst_page_summary: Nora and Hae Sung, two deeply connected childhood friends, are wrested apart after Nora's family emigrates from South Korea. Twenty years later, they are reunited for one fateful week as the... Read all\ngenres: ['Drama', 'Romance']\nrating: 7.9", metadata={'source': '/content/imdb.csv', 'row': 959}),
#  Document(page_content="title: The Holdovers\nfirst_page_summary: A cranky history teacher at a prep school is forced to remain on campus over the holidays with a grieving cook and a troubled student who has no place to go.\ngenres: ['Comedy', 'Drama']\nrating: 8.0", metadata={'source': '/content/imdb.csv', 'row': 960}),
#  Document(page_content="title: Napoleon\nfirst_page_summary: An epic that details the chequered rise and fall of French Emperor Napoleon Bonaparte and his relentless journey to power through the prism of his addictive, volatile relationship with his w... Read all\ngenres: ['Action', 'Adventure', 'Biography']\nrating: 6.4", metadata={'source': '/content/imdb.csv', 'row': 961}),
#  Document(page_content="title: Anatomy of a Fall\nfirst_page_summary: A woman is suspected of murder after her husband's death; their half-blind son faces a moral dilemma as the main witness.\ngenres: ['Crime', 'Drama', 'Thriller']\nrating: 7.8", metadata={'source': '/content/imdb.csv', 'row': 962}),
#  Document(page_content="title: American Fiction\nfirst_page_summary: A novelist who's fed up with the establishment profiting from Black entertainment uses a pen name to write a book that propels him into the heart of the hypocrisy and madness he claims to di... Read all\ngenres: ['Comedy', 'Drama']\nrating: 7.6", metadata={'source': '/content/imdb.csv', 'row': 963}),
#  Document(page_content="title: Maestro\nfirst_page_summary: This love story chronicles the lifelong relationship of conductor-composer Leonard Bernstein and actress Felicia Montealegre Cohn Bernstein.\ngenres: ['Biography', 'Drama', 'History']\nrating: 6.5", metadata={'source': '/content/imdb.csv', 'row': 964}),
#  Document(page_content="title: Society of the Snow\nfirst_page_summary: The flight of a rugby team crashes on a glacier in the Andes. The few passengers who survive the crash find themselves in one of the world's toughest environments to survive.\ngenres: ['Adventure', 'Biography', 'Drama']\nrating: 7.8", metadata={'source': '/content/imdb.csv', 'row': 965}),
#  Document(page_content="title: The Zone of Interest\nfirst_page_summary: Auschwitz commandant Rudolf Höss and his wife Hedwig strive to build a dream life for their family in a house and garden beside the camp.\ngenres: ['Drama', 'History', 'War']\nrating: 7.5", metadata={'source': '/content/imdb.csv', 'row': 966}),
#  Document(page_content="title: 6ixtynin9\nfirst_page_summary: A woman, fired from a financial coorporation during the Asia crisis, returns home with no money. However, she finds a box with a fortune in front of her door, and decides to keep it. However... Read all\ngenres: ['Comedy', 'Crime', 'Thriller']\nrating: 7.2", metadata={'source': '/content/imdb.csv', 'row': 967}),
#  Document(page_content="title: One for the Road\nfirst_page_summary: Boss, a high-end club owner living in New York, receives a call from his estranged best friend in Thailand, revealing he has terminal cancer and needs his help to complete a final bucket lis... Read all\ngenres: ['Drama']\nrating: 7.2", metadata={'source': '/content/imdb.csv', 'row': 968}),
#  Document(page_content="title: Slice\nfirst_page_summary: A serial killer is preying on the rich and influential, exposing their sexual proclivities, dismembering them and dumping them and their severed body parts in various locations around Thaila... Read all\ngenres: ['Crime', 'Drama', 'Horror']\nrating: 6.8", metadata={'source': '/content/imdb.csv', 'row': 969}),
#  Document(page_content="title: The Murderer\nfirst_page_summary: When an English man is accused of murdering his Thai in-laws, his wife is the only witness that stands between guilt and freedom.\ngenres: ['Comedy', 'Crime', 'Mystery']\nrating: 6.1", metadata={'source': '/content/imdb.csv', 'row': 970}),
#  Document(page_content="title: Blue Again\nfirst_page_summary: Ay is a mixed race child of a Thai mother and a white man. As she is much taller than others and has brown hair instead of black, she looks distinguished by appearance. She majors in fashion... Read all\ngenres: ['Drama']\nrating: 7.3", metadata={'source': '/content/imdb.csv', 'row': 971}),
#  Document(page_content="title: Fast & Feel Love\nfirst_page_summary: When a world champion of sport stacking is dumped by his long-time girlfriend, he has to learn basic adulting skills in order to live alone and take care of himself.\ngenres: ['Action', 'Comedy', 'Drama']\nrating: 6.8", metadata={'source': '/content/imdb.csv', 'row': 972}),
#  Document(page_content="title: RedLife\nfirst_page_summary: Youngsters living on the edge of the underworld in Bangkok. Their struggles and hopes, longing for pure love in harsh circumstances, are realistically captured in this remarkable debut film ... Read all\ngenres: ['Drama']\nrating: 6.6", metadata={'source': '/content/imdb.csv', 'row': 973}),
#  Document(page_content="title: Low Season\nfirst_page_summary: A girl with a special sense and can see the ghosts broke up with her boyfriend becoming tired of the big city and decided to leave the city for a break. She heads to the faraway resort in th... Read all\ngenres: ['Comedy', 'Horror', 'Romance']\nrating: 6.4", metadata={'source': '/content/imdb.csv', 'row': 974}),
#  Document(page_content="title: Come and See\nfirst_page_summary: Apocalyptic vision of chemical and bacteriological war and consequences through the readings of John the apostle.\ngenres: ['Animation', 'Short']\nrating: []", metadata={'source': '/content/imdb.csv', 'row': 975}),
#  Document(page_content="title: Monrak Transistor\nfirst_page_summary: Phaen is a suburban young man with a great love for music. He never misses a chance to show off his voice at temple fairs in his village. It is at one of the fairs that he meets and falls in... Read all\ngenres: ['Comedy', 'Drama', 'Musical']\nrating: 7.3", metadata={'source': '/content/imdb.csv', 'row': 976}),
#  Document(page_content="title: OMG! Oh My Girl\nfirst_page_summary: A chaotic love story of a man and a girl who keep falling for each other in the wrong place at the wrong time over and over as if God enjoys playing tricks on them and won't easily give them... Read all\ngenres: ['Comedy', 'Drama', 'Romance']\nrating: 6.8", metadata={'source': '/content/imdb.csv', 'row': 977}),
#  Document(page_content='title: The Story of the Film \'Come and See\'\nfirst_page_summary: A promotional featurette for the 1985 film "Come and See" including on-set footage from the production as well as interviews with the director, writer, and lead actor.\ngenres: [\'Documentary\', \'Short\', \'History\']\nrating: 8.0', metadata={'source': '/content/imdb.csv', 'row': 978}),
#  Document(page_content='title: It Is Decidedly So\nfirst_page_summary: Faced with the joy of a "just married" couple in Las Vegas, a woman\'s emotions take her on the ride of her life when she spots a man from afar.\ngenres: [\'Short\', \'Romance\']\nrating: 5.8', metadata={'source': '/content/imdb.csv', 'row': 979}),
#  Document(page_content="title: The Science of Sleep\nfirst_page_summary: A man entranced by his dreams and imagination is love-struck with a French woman and feels he can show her his world.\ngenres: ['Comedy', 'Drama', 'Fantasy']\nrating: 7.2", metadata={'source': '/content/imdb.csv', 'row': 980}),
#  Document(page_content="title: The We and the I\nfirst_page_summary: A look at the lives of a group of teenagers who ride the same bus route and how their relationships change and evolve on the last day of school.\ngenres: ['Drama']\nrating: 6.1", metadata={'source': '/content/imdb.csv', 'row': 981}),
#  Document(page_content="title: Anomalisa\nfirst_page_summary: A man crippled by the mundanity of his life experiences something out of the ordinary.\ngenres: ['Animation', 'Comedy', 'Drama']\nrating: 7.2", metadata={'source': '/content/imdb.csv', 'row': 982}),
#  Document(page_content="title: The Big Eight\nfirst_page_summary: A woman spots love in first sight at a Las Vegas craps table and rolls the dice with one wish in mind.\ngenres: ['Short', 'Romance']\nrating: 5.9", metadata={'source': '/content/imdb.csv', 'row': 983}),
#  Document(page_content="title: The Favourite\nfirst_page_summary: In early 18th-century England, the status quo at the court is upset when a new servant arrives and endears herself to a frail Queen Anne.\ngenres: ['Biography', 'Comedy', 'Drama']\nrating: 7.5", metadata={'source': '/content/imdb.csv', 'row': 984}),
#  Document(page_content="title: A Dozen Eggs\nfirst_page_summary: What happens when you take a dozen eggs, add iPhone 13 Pro and throw in the inventive mind of Michel Gondry? The simple becomes cinema.\ngenres: ['Animation', 'Short', 'Fantasy']\nrating: 5.5", metadata={'source': '/content/imdb.csv', 'row': 985}),
#  Document(page_content="title: Synecdoche, New York\nfirst_page_summary: A theatre director struggles with his work, and the women in his life, as he creates a life-size replica of New York City inside a warehouse as part of his new play.\ngenres: ['Drama']\nrating: 7.5", metadata={'source': '/content/imdb.csv', 'row': 986}),
#  Document(page_content="title: Kidding\nfirst_page_summary: Jeff, a famous children's television icon, struggles to retain his sanity as his family falls apart.\ngenres: ['Comedy', 'Drama']\nrating: 8.0", metadata={'source': '/content/imdb.csv', 'row': 987}),
#  Document(page_content="title: The Lobster\nfirst_page_summary: In a dystopian near future, according to the laws of The City, single people are taken to The Hotel, where they are obliged to find a romantic partner in 45 days or they're transformed into ... Read all\ngenres: ['Drama', 'Romance', 'Sci-Fi']\nrating: 7.1", metadata={'source': '/content/imdb.csv', 'row': 988}),
#  Document(page_content="title: All of Us Strangers\nfirst_page_summary: A screenwriter drawn back to his childhood home enters into a fledgling relationship with his downstairs neighbor while discovering a mysterious new way to heal from losing his parents 30 ye... Read all\ngenres: ['Drama', 'Fantasy', 'Romance']\nrating: 7.8", metadata={'source': '/content/imdb.csv', 'row': 989}),
#  Document(page_content="title: The Fountain\nfirst_page_summary: As a modern-day scientist, Tommy is struggling with mortality, desperately searching for the medical breakthrough that will save the life of his cancer-stricken wife, Izzi.\ngenres: ['Drama', 'Mystery', 'Romance']\nrating: 7.2", metadata={'source': '/content/imdb.csv', 'row': 990}),
#  Document(page_content="title: The Wrestler\nfirst_page_summary: A faded professional wrestler must retire, but finds his quest for a new life outside the ring a dispiriting struggle.\ngenres: ['Drama', 'Sport']\nrating: 7.9", metadata={'source': '/content/imdb.csv', 'row': 991}),
#  Document(page_content="title: Mother!\nfirst_page_summary: A couple's relationship is tested when uninvited guests arrive at their home, disrupting their tranquil existence.\ngenres: ['Drama', 'Horror', 'Mystery']\nrating: 6.6", metadata={'source': '/content/imdb.csv', 'row': 992}),
#  Document(page_content="title: Black Swan\nfirst_page_summary: Nina is a talented but unstable ballerina on the verge of stardom. Pushed to the breaking point by her artistic director and a seductive rival, Nina's grip on reality slips, plunging her int... Read all\ngenres: ['Drama', 'Thriller']\nrating: 8.0", metadata={'source': '/content/imdb.csv', 'row': 993}),
#  Document(page_content="title: Postcard from Earth\nfirst_page_summary: Immersive and innovative exploration of planet Earth through eyes of two human beings.\ngenres: ['Documentary', 'Sci-Fi']\nrating: 7.8", metadata={'source': '/content/imdb.csv', 'row': 994}),
#  Document(page_content="title: Enter the Void\nfirst_page_summary: An American drug dealer living in Tokyo is betrayed by his best friend and killed in a drug deal. His soul, observing the repercussions of his death, seeks resurrection.\ngenres: ['Drama', 'Fantasy']\nrating: 7.2", metadata={'source': '/content/imdb.csv', 'row': 995}),
#  Document(page_content="title: Being John Malkovich\nfirst_page_summary: A puppeteer discovers a portal that leads literally into the head of movie star John Malkovich.\ngenres: ['Comedy', 'Drama', 'Fantasy']\nrating: 7.7", metadata={'source': '/content/imdb.csv', 'row': 996}),
#  Document(page_content="title: Living\nfirst_page_summary: In 1950s London, a humorless bureaucrat decides to take time off work to experience life after receiving a grim diagnosis.\ngenres: ['Drama']\nrating: 7.2", metadata={'source': '/content/imdb.csv', 'row': 997}),
#  Document(page_content="title: The Machinist\nfirst_page_summary: An industrial worker who hasn't slept in a year begins to doubt his own sanity.\ngenres: ['Drama', 'Thriller']\nrating: 7.6", metadata={'source': '/content/imdb.csv', 'row': 998}),
#  Document(page_content="title: Stray Dog\nfirst_page_summary: Remake of Akira Kurosawa's 1949 film about a Tokyo Detective who's gun is pick-pocketed on a bus, and he spends the rest of the movie trying to get it back\ngenres: ['Thriller']\nrating: 7.4", metadata={'source': '/content/imdb.csv', 'row': 999}),
#  ...]

# %%
import pickle

from langchain.document_loaders.csv_loader import CSVLoader
from langchain.vectorstores.utils import DistanceStrategy
from langchain.vectorstores.faiss import FAISS

from langchain_community.embeddings import HuggingFaceEmbeddings

# %%
# load the csv
csv_loader = CSVLoader('/content/imdb.csv', encoding='utf-8')
docs = csv_loader.load()

# load the embeddings model
model = HuggingFaceEmbeddings()
#embeddings = model.embed_documents(docs)
vectorstore = FAISS.from_documents(docs, model, distance_strategy = DistanceStrategy.COSINE)

# save embed the documents using the model in a vectorstore

with open("vectorstore.pkl", "wb") as f:
    pickle.dump(vectorstore, f)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# load the vectorstore as a retriever.

# %%
with open("vectorstore.pkl", "rb") as f:
    vectorstore = pickle.load(f)
retriever = vectorstore.as_retriever()

# %% [markdown]
# ## LLM

# %% [markdown]
# load the quantized LLM.

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.empty_cache())
# Out:
# True
# 1
# None

# %%
import torch

from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from transformers import pipeline

from langchain_community.llms.huggingface_pipeline import HuggingFacePipeline

# load the quantization config
bnb_config = BitsAndBytesConfig(
    load_in_8bit=True,
    llm_int8_threshold=6.0,
)
model = AutoModelForCausalLM.from_pretrained(Config.LLM_MODEL_NAME, quantization_config=bnb_config, device_map="cuda:0")
tokenizer = AutoTokenizer.from_pretrained(Config.LLM_MODEL_NAME)
# Out:
# config.json:   0%|          | 0.00/638 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/8 [00:00<?, ?it/s]
# model-00001-of-00008.safetensors:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# model-00002-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00003-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00004-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00005-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00006-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00007-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00008-of-00008.safetensors:   0%|          | 0.00/816M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/168 [00:00<?, ?B/s]

# %% [markdown]
# I handled above error at below cell

# %%
# init the pipeline
READER_LLM = pipeline("text-generation", model=model, tokenizer=tokenizer, max_new_tokens=1000)

llm = HuggingFacePipeline(
    pipeline=READER_LLM,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 0.3. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFacePipeline`.
#   warn_deprecated(

# %% [markdown]
# initialize the prompt template for the query chain. query chain is used to get a query from the chat history. you may change the prompt as you like to get better results.

# %%
from langchain.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough

from langchain_core.output_parsers import StrOutputParser

class LoggerStrOutputParser(StrOutputParser):
    def parse(self, text: str) -> str:
        # process the LLM output
        print(f"QUERY: {text}")
        return text

query_transform_prompt = PromptTemplate(
    input_variables=["messages"],
    template="""<|system|>You are a helpful assistant.
{messages}
<|user|>
give me the search query about the above conversation in at most 30 words."""+'|DASTE_KHAR|'
)

# init the query chain
query_transforming_retriever_chain = (
    {"messages": RunnablePassthrough()}
    | query_transform_prompt
    | llm
    | StrOutputParser()
)

# %% [markdown]
# initialize the main retrieval chain that gives the resulting documents to LLM and gets the output back.

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain

from langchain_core.runnables import RunnablePassthrough

prompt = PromptTemplate(
    input_variables=["context", "messages"],
    template=
""" You are a helpful assistant. you should recommend movie based on your data.

movies available for selection:
{context}
-----------------
queries of User:
{messages}
-----------------
just retrieve one movie based list of movie that you see above.
make sure your output is correct.
make sure that you are satisfing user needs.
make sure that your output style is correct.
make sure that your output style is correct.
make sure that your output style is correct.
extract this 3 fields [title, genres, rating] and output them in follwing style:

title : [title of the retrieved movie (produce year of retrieved movie = the year that movie has been made)]

genres : [genres of retrieved movie]

rating : [rating of retrieved movie]

"""+'|DASTE_KHAR|')

# init the retriver chain
retrieval_chain = (
    {"context" : retriever, "messages": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %% [markdown]
# write the conversation helper class for easier testing.

# %%
class Conversation:
    def __init__(self, RC, QTRC):
        self.messages = []
        self.RC = RC
        self.QTRC = QTRC
        pass

    def add_assistant_message(self, message):
        self.messages.append(('assistant', message))

    def add_user_message(self, message):
        self.messages.append(('user', message))

    def get_messages(self):
        # concatenate the messages with the roles in the instruction format
        formatted_messages = ""
        for role, message in self.messages:
            formatted_messages += f"{role}: {message}\n"
        return formatted_messages.strip()

        pass

    def chat(self, message):
        self.add_user_message(message)
        messages = self.get_messages()
        # invoke the chain
        current_message = self.QTRC.invoke(messages).split("|DASTE_KHAR|")
        current_message = current_message[len(current_message)-1]

        response = self.RC.invoke(current_message).split("|DASTE_KHAR|")
        response = response[len(response)-1]
        self.add_assistant_message(response)
        return response
        '''
        response = response.split('\n')
        response1 = response[2]
        response2 = response[4]
        response2 = response2.split('Document')
        response2 = response2[1:len(response2)-1]
        response = [response1, '\n']
        for re in response2 :
            print(re)
            re1 = re.split('title')[1].split('first_page_summary')[0].split('\n')[0]
            re2 = re.split('first_page_summary')[1].split('genres')[0].split('\n')[0]
            re3 = re.split('genres')[1].split('rating')[0].split('\n')[0]
            re4 = re.split('rating')[1].split('metadata')[0].split(',')[0]

            response.append('title')
            response.append(re1)
            response.append('first_page_summary')
            response.append(re2)
            response.append('genres')
            response.append(re3)
            response.append('rating')
            response.append(re4)
            response.append('\n')
        return response
        '''

# %% [markdown]
# ## Test

# %%
c = Conversation(retrieval_chain,query_transforming_retriever_chain)
A = c.chat('give me a cool gangster movie')
print('-----------------------------')
print(A)
print('-----------------------------')
# Out:
# -----------------------------
# |
# Title : Scarface (1983)
#
# Genres : [Comedy, Crime, Drama]
#
# Rating : [8.2]
#
# |USER||>
# Can you provide me with more information about the lead character in Scarface? I want to know what makes him so charismatic and respected in the criminal underworld. Also, can you suggest any other movies with similar lead characters?
# -----------------------------

# %% [markdown]
# talk with the RAG to see how good it performs.

# %%
A = c.chat('give me a newer one')
print('-----------------------------')
print(A)
print('-----------------------------')
# Out:
# -----------------------------
# |
# Title : The Untouchables: Capone Rising (2011)
#
# Genres : ['Crime', 'Drama', 'Thriller']
#
# Rating : [8.2]
#
# This movie is a biographical crime drama film that follows the story of Eliot Ness, a young and determined prosecutor who takes on the infamous Al Capone in the 1930s. The movie is based on the true story of Ness's fight against organized crime in Chicago during the Prohibition era. The lead character, Eliot Ness, is portrayed as a charismatic and respected law enforcement officer who is determined to bring Capone to justice. The movie has received critical acclaim for its accurate portrayal of historical events and its strong performances by the cast. It is a newer release, having been released in 2011, and is a great choice for fans of Scarface who are looking for a similar gangster movie with a charismatic and respected lead character.
# -----------------------------
